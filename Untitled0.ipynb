# %%
# !git clone https://github.com/NGQ-Hiro/test
# Out:
# Cloning into 'test'...
# remote: Enumerating objects: 320, done.
# remote: Counting objects: 100% (320/320), done.
# remote: Compressing objects: 100% (315/315), done.
# remote: Total 320 (delta 0), reused 320 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (320/320), 14.99 MiB | 21.78 MiB/s, done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/test')

# %%
# !ls /content/test
# Out:
# data  Going_modular.ipynb
